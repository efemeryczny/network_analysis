# %% [markdown]
# <a href="https://colab.research.google.com/github/efemeryczny/network_analysis/blob/main/rysunki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph
G = nx.DiGraph()

# Add nodes
G.add_node(1)
G.add_node(2)
G.add_node(3)

# Add directed edges
G.add_edge(1, 2)
G.add_edge(2, 3)
G.add_edge(3, 1)

# Set edge weights
G.edges[1, 2]['weight'] = 0.6
G.edges[2, 3]['weight'] = 0.8
G.edges[3, 1]['weight'] = 0.4

# Draw the graph
pos = nx.spring_layout(G)  # Set the layout algorithm

# Draw nodes
nx.draw_networkx_nodes(G, pos, node_size=200, node_color='lightblue')

# Draw edges
nx.draw_networkx_edges(G, pos, arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Set node labels
node_labels = {node: node for node in G.nodes()}
nx.draw_networkx_labels(G, pos, labels=node_labels)

# Show the graph
plt.axis('off')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()

# Add nodes
G.add_node(1)
G.add_node(2)
G.add_node(3)

# Add undirected edges
G.add_edge(1, 2)
G.add_edge(2, 3)

# Add directed edges
G.add_edge(3, 1, direction='forward')
G.add_edge(1, 3, direction='backward')

# Set edge weights
G.edges[1, 2]['weight'] = 0.6
G.edges[2, 3]['weight'] = 0.8
G.edges[3, 1]['weight'] = 0.4
G.edges[1, 3]['weight'] = 0.2

# Draw the graph
pos = nx.spring_layout(G)  # Set the layout algorithm

# Draw nodes
nx.draw_networkx_nodes(G, pos, node_size=200, node_color='lightblue')

# Draw undirected edges
nx.draw_networkx_edges(G, pos, edgelist=G.edges(), arrows=False)

# Draw directed edges
directed_edges = [(u, v) for (u, v, d) in G.edges(data=True) if 'direction' in d]
nx.draw_networkx_edges(G, pos, edgelist=directed_edges, arrows=True)

# Draw edge labels
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

# Set node labels
node_labels = {node: node for node in G.nodes()}
nx.draw_networkx_labels(G, pos, labels=node_labels)

# Show the graph
plt.axis('off')
plt.show()

# %%
# Create a directed graph
directed_graph = nx.DiGraph()
directed_graph.add_node(1)
directed_graph.add_node(2)
directed_graph.add_edge(1, 2)

# Create an undirected graph
undirected_graph = nx.Graph()
undirected_graph.add_node(1)
undirected_graph.add_node(2)
undirected_graph.add_edge(1, 2)

# Create a weighted graph
weighted_graph = nx.Graph()
weighted_graph.add_node(1)
weighted_graph.add_node(2)
weighted_graph.add_edge(1, 2, weight=0.6)

# Create a graph with self-loop
self_loop_graph = nx.DiGraph()
self_loop_graph.add_node(1)
self_loop_graph.add_edge(1, 1)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Plot directed graph
pos_directed = nx.spring_layout(directed_graph)
axs[0, 0].set_title("Directed Graph")
nx.draw_networkx(directed_graph, pos=pos_directed, with_labels=True, ax=axs[0, 0])

# Plot undirected graph
pos_undirected = nx.spring_layout(undirected_graph)
axs[0, 1].set_title("Undirected Graph")
nx.draw_networkx(undirected_graph, pos=pos_undirected, with_labels=True, ax=axs[0, 1])

# Plot weighted graph
pos_weighted = nx.spring_layout(weighted_graph)
axs[1, 0].set_title("Weighted Graph")
nx.draw_networkx(weighted_graph, pos=pos_weighted, with_labels=True, ax=axs[1, 0])

# Plot graph with self-loop
pos_self_loop = nx.spring_layout(self_loop_graph)
axs[1, 1].set_title("Graph with Self-loop")
nx.draw_networkx(self_loop_graph, pos=pos_self_loop, with_labels=True, ax=axs[1, 1])

# Adjust spacing between subplots
plt.tight_layout()

# Show the graphs
plt.show()

# %%
# Create a directed graph
directed_graph = nx.DiGraph()
directed_graph.add_node('X')
directed_graph.add_node('Y')
directed_graph.add_edge('X', 'Y')

# Create an undirected graph
undirected_graph = nx.Graph()
undirected_graph.add_node('X')
undirected_graph.add_node('Y')
undirected_graph.add_edge('X', 'Y')

# Create a weighted graph
weighted_graph = nx.DiGraph()
weighted_graph.add_node('X')
weighted_graph.add_node('Y')
weighted_graph.add_node('Z')
weighted_graph.add_edge('X', 'Y', weight=0.2)
weighted_graph.add_edge('X', 'Z', weight=1)
weighted_graph.add_edge('Z', 'Y', weight=0.8)

# Create a graph with self-loop
self_loop_graph = nx.DiGraph()
self_loop_graph.add_node('X')
self_loop_graph.add_edge('X', 'X')

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Plot directed graph
pos_directed = nx.spring_layout(directed_graph)
axs[0, 0].set_title("Relacja skierowana")
nx.draw_networkx(directed_graph, pos=pos_directed, arrowsize=30, with_labels=True, ax=axs[0, 0], node_size=1000, font_size=12, font_weight='bold')

# Plot undirected graph
pos_undirected = nx.spring_layout(undirected_graph)
axs[0, 1].set_title("Relacja nieskierowana")
nx.draw_networkx(undirected_graph, pos=pos_undirected, with_labels=True, ax=axs[0, 1], node_size=1000, font_size=12, font_weight='bold')

# Plot weighted graph
pos_weighted = nx.circular_layout(weighted_graph)
axs[1, 0].set_title("Graf ważony")
nx.draw_networkx(weighted_graph, pos=pos_weighted, with_labels=True, ax=axs[1, 0], node_size=1000, font_size=12, font_weight='bold')
edge_labels_weighted = nx.get_edge_attributes(weighted_graph, 'weight')
nx.draw_networkx_edge_labels(weighted_graph, pos=pos_weighted, edge_labels=edge_labels_weighted, ax=axs[1, 0])


# Plot graph with self-loop
pos_self_loop = nx.spring_layout(self_loop_graph)
axs[1, 1].set_title("Pętla")
nx.draw_networkx(self_loop_graph, pos=pos_self_loop, with_labels=True, ax=axs[1, 1], node_size=1000, font_size=12, font_weight='bold')

# Adjust spacing between subplots
plt.tight_layout()

# Show the graphs
plt.show()

# %%
import networkx as nx

# Load the Karate Club network
karate = nx.karate_club_graph()
nx.draw(karate)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Load the Karate Club network
karate = nx.karate_club_graph()

# Calculate centrality measures
degree_centrality = nx.degree_centrality(karate)
closeness_centrality = nx.closeness_centrality(karate)
betweenness_centrality = nx.betweenness_centrality(karate)
eigenvector_centrality = nx.eigenvector_centrality(karate)
pagerank = nx.pagerank(karate)
hits_authority = nx.hits(karate)[1]
hits_hub = nx.hits(karate)[0]

# Define node colors based on degree centrality
node_colors = [degree_centrality[node] for node in karate.nodes]

# Define edge widths based on edge weights
edge_widths = [karate[u][v].get('weight', 1) for u, v in karate.edges]

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Draw the graph
pos = nx.spring_layout(karate, seed=42)
nx.draw_networkx(karate, pos=pos, ax=ax, node_color=node_colors, edge_color='gray', width=edge_widths,
                 node_size=300, alpha=0.8, with_labels=True, cmap=plt.cm.Blues)

# Add centrality measures as node labels
labels = {
    node: f"DC: {degree_centrality[node]:.2f}\nCC: {closeness_centrality[node]:.2f}\n"
           f"BC: {betweenness_centrality[node]:.2f}\nEC: {eigenvector_centrality[node]:.2f}\n"
           f"PR: {pagerank[node]:.2f}\nH_A: {hits_authority[node]:.2f}\nH_H: {hits_hub[node]:.2f}"
    for node in karate.nodes
}
nx.draw_networkx_labels(karate, pos=pos, labels=labels, font_size=8, font_color='black')

# Set plot title and axis labels
plt.title("Karate Club Network with Centrality Measures")
plt.xlabel("X")
plt.ylabel("Y")

# Add a colorbar legend for node colors
sm = plt.cm.ScalarMappable(cmap=plt.cm.Blues, norm=plt.Normalize(vmin=min(node_colors), vmax=max(node_colors)))
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label("Degree Centrality")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-17-8aab383ec10e>:47: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
# Load the Karate Club network
karate = nx.karate_club_graph()

# Calculate degree centrality
degree_centrality = nx.degree_centrality(karate)

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Draw the graph with node colors based on degree centrality
pos = nx.spring_layout(karate, seed=42)
nx.draw_networkx(karate, pos=pos, ax=ax, node_color=list(degree_centrality.values()), edge_color='gray',
                 cmap=plt.cm.Blues, node_size=300, alpha=0.8, with_labels=True)

# Set plot title and axis labels
plt.title("Karate Club Network with Degree Centrality")
plt.xlabel("X")
plt.ylabel("Y")

# Add a colorbar legend for degree centrality
sm = plt.cm.ScalarMappable(cmap=plt.cm.Blues, norm=plt.Normalize(vmin=min(degree_centrality.values()),
                                                                  vmax=max(degree_centrality.values())))
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label("Degree Centrality")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-bc40eaf7ace8>:24: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Load the Karate Club network
karate = nx.karate_club_graph()

# Calculate betweenness centrality
betweenness_centrality = nx.betweenness_centrality(karate)

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Draw the graph with node colors based on betweenness centrality
pos = nx.spring_layout(karate, seed=42)
nx.draw_networkx(karate, pos=pos, ax=ax, node_color=list(betweenness_centrality.values()), edge_color='gray',
                 cmap=plt.cm.Blues, node_size=300, alpha=0.8, with_labels=True)

# Set plot title and axis labels
plt.title("Karate Club Network with Betweenness Centrality")
plt.xlabel("X")
plt.ylabel("Y")

# Add a colorbar legend for betweenness centrality
sm = plt.cm.ScalarMappable(cmap=plt.cm.Blues, norm=plt.Normalize(vmin=min(betweenness_centrality.values()),
                                                                  vmax=max(betweenness_centrality.values())))
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label("Betweenness Centrality")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-42f947660af6>:27: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
karate = nx.karate_club_graph()

# Calculate closeness centrality
closeness_centrality = nx.closeness_centrality(karate)

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Draw the graph with node colors based on closeness centrality
pos = nx.spring_layout(karate, seed=42)
nx.draw_networkx(karate, pos=pos, ax=ax, node_color=list(closeness_centrality.values()), edge_color='gray',
                 cmap=plt.cm.Blues, node_size=300, alpha=0.8, with_labels=True)

# Set plot title and axis labels
plt.title("Karate Club Network with Closeness Centrality")
plt.xlabel("X")
plt.ylabel("Y")

# Add a colorbar legend for closeness centrality
sm = plt.cm.ScalarMappable(cmap=plt.cm.Blues, norm=plt.Normalize(vmin=min(closeness_centrality.values()),
                                                                  vmax=max(closeness_centrality.values())))
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label("Closeness Centrality")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-20-f4009f32d4e1>:23: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
# Load the Karate Club network
karate = nx.karate_club_graph()

# Calculate eigenvector centrality
eigenvector_centrality = nx.eigenvector_centrality(karate)

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Draw the graph with node colors based on eigenvector centrality
pos = nx.spring_layout(karate, seed=42)
nx.draw_networkx(karate, pos=pos, ax=ax, node_color=list(eigenvector_centrality.values()), edge_color='gray',
                 cmap=plt.cm.Blues, node_size=300, alpha=0.8, with_labels=True)

# Set plot title and axis labels
plt.title("Karate Club Network with Eigenvector Centrality")
plt.xlabel("X")
plt.ylabel("Y")

# Add a colorbar legend for eigenvector centrality
sm = plt.cm.ScalarMappable(cmap=plt.cm.Blues, norm=plt.Normalize(vmin=min(eigenvector_centrality.values()),
                                                                  vmax=max(eigenvector_centrality.values())))
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label("Eigenvector Centrality")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-21-804a51aabecb>:24: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)

# %%
karate = nx.karate_club_graph()

# Calculate PageRank centrality
pagerank_centrality = nx.pagerank(karate)

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Draw the graph with node colors based on PageRank centrality
pos = nx.spring_layout(karate, seed=42)
nx.draw_networkx(karate, pos=pos, ax=ax, node_color=list(pagerank_centrality.values()), edge_color='gray',
                 cmap=plt.cm.Blues, node_size=300, alpha=0.8, with_labels=True)

# Set plot title and axis labels
plt.title("Karate Club Network with PageRank Centrality")
plt.xlabel("X")
plt.ylabel("Y")

# Add a colorbar legend for PageRank centrality
sm = plt.cm.ScalarMappable(cmap=plt.cm.Blues, norm=plt.Normalize(vmin=min(pagerank_centrality.values()),
                                                                  vmax=max(pagerank_centrality.values())))
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label("PageRank Centrality")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-2ccb9e254690>:23: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)
